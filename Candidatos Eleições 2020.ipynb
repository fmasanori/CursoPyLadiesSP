# %% [markdown]
# #### Os dados, até a data do presente estudo, estão no https://www.tse.jus.br/eleicoes/estatisticas/repositorio-de-dados-eleitorais-1/repositorio-de-dados-eleitorais

# %%
import pandas as pd
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
filename = r'C:\Users\fmasa\Downloads\consulta_cand_2020\consulta_cand_2020_BRASIL.csv'
df = pd.read_csv(filename, delimiter=';', 
                 encoding='ISO-8859-1')

# %%
df.shape
# Out:
# (557633, 63)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557633 entries, 0 to 557632
# Data columns (total 63 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DT_GERACAO                     557633 non-null  object
#  1   HH_GERACAO                     557633 non-null  object
#  2   ANO_ELEICAO                    557633 non-null  int64
#  3   CD_TIPO_ELEICAO                557633 non-null  int64
#  4   NM_TIPO_ELEICAO                557633 non-null  object
#  5   NR_TURNO                       557633 non-null  int64
#  6   CD_ELEICAO                     557633 non-null  int64
#  7   DS_ELEICAO                     557633 non-null  object
#  8   DT_ELEICAO                     557633 non-null  object
#  9   TP_ABRANGENCIA                 557633 non-null  object
#  10  SG_UF                          557633 non-null  object
#  11  SG_UE                          557633 non-null  int64
# ...

# %%
df.sample(10)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 74707   20/11/2020   20:16:52         2020                2
# 375755  20/11/2020   20:16:52         2020                2
# 211378  20/11/2020   20:16:52         2020                2
# 507706  20/11/2020   20:16:52         2020                2
# 118497  20/11/2020   20:16:52         2020                2
# 106628  20/11/2020   20:16:52         2020                2
# 268613  20/11/2020   20:16:52         2020                2
# 402545  20/11/2020   20:16:52         2020                2
# 335996  20/11/2020   20:16:52         2020                2
# 248359  20/11/2020   20:16:52         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO                DS_ELEICAO  \
# 74707   ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
# 375755  ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
# 211378  ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
# ...

# %%
df.groupby('DS_GENERO').size().sort_values()
# Out:
# DS_GENERO
# FEMININO     187081
# MASCULINO    370552
# dtype: int64

# %%
df.groupby('DS_GRAU_INSTRUCAO').size().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='DS_GRAU_INSTRUCAO'>

# %%
df.groupby('DS_COR_RACA').size().sort_values()
# Out:
# DS_COR_RACA
# AMARELA             1962
# INDÍGENA            2216
# SEM INFORMAÇÃO      6366
# PRETA              58697
# PARDA             220307
# BRANCA            268085
# dtype: int64

# %%
df.groupby('NR_IDADE_DATA_POSSE').size().sort_values().tail(10).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='NR_IDADE_DATA_POSSE'>
